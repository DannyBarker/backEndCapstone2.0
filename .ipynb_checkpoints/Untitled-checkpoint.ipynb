# %%
import pandas as pd
import sqlite3 as sql
import folium
from folium import plugins
from folium.plugins import MarkerCluster
import geopandas as gpd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns

# %matplotlib inline

# %%
conn = sql.connect("db.sqlite3")
pay_df = pd.read_sql_query("SELECT * FROM capstone_payment;", conn)

# %%
pay_df.head()
# Out:
#    id payment_date  amount_donated  description  customer_id  giftcard_id
# 0   1   2019-10-29            0.33   I donated!            2            1
# 1   2   2019-10-29            0.17   I donated!            1            2
# 2   3   2019-10-29            1.43  I donated!!            2            5
# 3   4   2019-10-29            0.26   I donated!            1            6
# 4   5   2019-10-29            2.78   I donated!            2            4

# %%
cust_df = pd.read_sql_query("SELECT * FROM capstone_customer;", conn)
cust_df.head()
# Out:
#    id phone_number         address         city      state  zipcode  \
# 0   1   1234567890       Olivia st  Nolensville         TN    37135
# 1   2   1234567890      123 street    Brentwood  Tennessee    37027
# 2   3   1234567890  Shannon Street    Nashville  Tennessee    37027
# 3   4   1234567890     McDonald St    Brentwood  Tennessee    37027
# 4   5   1234567890      forever st    Nashville         TN    37027
#
#    company_id  userType_id  user_id
# 0         NaN            1        1
# 1         NaN            1        2
# 2         1.0            2        3
# 3         2.0            2        4
# 4         3.0            2        5

# %%
payment_zipcode = pd.merge(pay_df, cust_df, left_on="customer_id", right_on="id")
payment_zipcode.head()
# Out:
#    id_x payment_date  amount_donated  description  customer_id  giftcard_id  \
# 0     1   2019-10-29            0.33   I donated!            2            1
# 1     3   2019-10-29            1.43  I donated!!            2            5
# 2     5   2019-10-29            2.78   I donated!            2            4
# 3     2   2019-10-29            0.17   I donated!            1            2
# 4     4   2019-10-29            0.26   I donated!            1            6
#
#    id_y phone_number     address         city      state  zipcode  company_id  \
# 0     2   1234567890  123 street    Brentwood  Tennessee    37027         NaN
# 1     2   1234567890  123 street    Brentwood  Tennessee    37027         NaN
# 2     2   1234567890  123 street    Brentwood  Tennessee    37027         NaN
# 3     1   1234567890   Olivia st  Nolensville         TN    37135         NaN
# 4     1   1234567890   Olivia st  Nolensville         TN    37135         NaN
#
#    userType_id  user_id
# 0            1        2
# 1            1        2
# 2            1        2
# 3            1        1
# 4            1        1

# %%
card_df = pd.read_sql_query("SELECT * FROM capstone_giftcard;", conn)
card_df.head()
# Out:
#    id          barcode  initial_balance  remaining_balance  company_id
# 0   1  s93827647381923             50.0               0.00           1
# 1   2  m57462994823354             25.0               0.00           2
# 2   3  f05721154893222             75.0               1.48           3
# 3   4  n84036888893255            150.0               0.00           4
# 4   5  s98236675833321            300.0               0.00           1

# %%
company_df = pd.read_sql_query("SELECT * FROM capstone_company;", conn)

# %%
company_df.head()
# Out:
#    id                 name
# 0   1  Shannon's Hair Shop
# 1   2            McDonalds
# 2   3           Forever 21
# 3   4                 Nike

# %%
company_card_df = pd.merge(card_df, company_df, left_on="company_id", right_on="id")
company_card_df.head()
# Out:
#    id_x          barcode  initial_balance  remaining_balance  company_id  \
# 0     1  s93827647381923             50.0               0.00           1
# 1     5  s98236675833321            300.0               0.00           1
# 2     6  s43655477684422            175.0               0.00           1
# 3     7  s19304662852220             75.0               0.00           1
# 4     8  s38299943872160             45.0               1.13           1
#
#    id_y                 name
# 0     1  Shannon's Hair Shop
# 1     1  Shannon's Hair Shop
# 2     1  Shannon's Hair Shop
# 3     1  Shannon's Hair Shop
# 4     1  Shannon's Hair Shop

# %%
payment_company_zip_df = pd.merge(payment_zipcode, company_card_df, left_on="giftcard_id", right_on="id_x")
payment_company_zip_df.head()
# Out:
#    id_x_x payment_date  amount_donated  description  customer_id  giftcard_id  \
# 0       1   2019-10-29            0.33   I donated!            2            1
# 1       3   2019-10-29            1.43  I donated!!            2            5
# 2       5   2019-10-29            2.78   I donated!            2            4
# 3       2   2019-10-29            0.17   I donated!            1            2
# 4       4   2019-10-29            0.26   I donated!            1            6
#
#    id_y_x phone_number     address         city  ... company_id_x  \
# 0       2   1234567890  123 street    Brentwood  ...          NaN
# 1       2   1234567890  123 street    Brentwood  ...          NaN
# 2       2   1234567890  123 street    Brentwood  ...          NaN
# 3       1   1234567890   Olivia st  Nolensville  ...          NaN
# 4       1   1234567890   Olivia st  Nolensville  ...          NaN
#
#    userType_id  user_id  id_x_y          barcode  initial_balance  \
# 0            1        2       1  s93827647381923             50.0
# 1            1        2       5  s98236675833321            300.0
# 2            1        2       4  n84036888893255            150.0
# 3            1        1       2  m57462994823354             25.0
# 4            1        1       6  s43655477684422            175.0
#
#   remaining_balance  company_id_y  id_y_y                 name
# 0               0.0             1       1  Shannon's Hair Shop
# 1               0.0             1       1  Shannon's Hair Shop
# 2               0.0             4       4                 Nike
# 3               0.0             2       2            McDonalds
# 4               0.0             1       1  Shannon's Hair Shop
#
# [5 rows x 22 columns]

# %%
payment_company_zip_df.columns.values
# Out:
# array(['id_x_x', 'payment_date', 'amount_donated', 'description',
#        'customer_id', 'giftcard_id', 'id_y_x', 'phone_number', 'address',
#        'city', 'state', 'zipcode', 'company_id_x', 'userType_id',
#        'user_id', 'id_x_y', 'barcode', 'initial_balance',
#        'remaining_balance', 'company_id_y', 'id_y_y', 'name'],
#       dtype=object)

# %%
final_df = payment_company_zip_df[['payment_date', 'amount_donated', 'zipcode', 'id_y_y', 'name']]
final_df = final_df.rename(columns={'id_y_y': 'company_id'})
final_df = final_df[final_df.company_id==1]
final_df = final_df.groupby("zipcode")["amount_donated"].sum().reset_index()
final_df.head()
# Out:
#    zipcode  amount_donated
# 0    37027            1.76
# 1    37135            0.26
# 2    90201            0.67

# %%
# final_df.zipcode = final_df[final_df.company_id==]

# %%
geo_df = pd.read_json("./data/USCities.json", orient="records")
geo_df.head()
# Out:
#          city     county latitude longitude state  zip_code
# 0  Holtsville    Suffolk  40.9223  -72.6371    NY       501
# 1  Holtsville    Suffolk  40.9223  -72.6371    NY       544
# 2    Adjuntas   Adjuntas  18.1653  -66.7226    PR       601
# 3      Aguada     Aguada  18.3931   -67.181    PR       602
# 4   Aguadilla  Aguadilla  18.4559  -67.1458    PR       603

# %%
# zipcode_gdf = gpd.read_file("./data/tl_2019_us_zcta510.geojson")
# zipcode_gdf.head()

# %%
# zipcode_gdf = zipcode_gdf[["ZCTA5CE10", "geometry"]]
# zipcode_gdf.to_pickle("data/zipcodes.pickle")

# %%
# zipcode_gdf.crs

# %%
my_crs = "{'init': 'epsg:4326'}"

# %%
zipcodes_pickle = pd.read_pickle("data/zipcodes.pickle")
zipcodes_pickle_gdf = gpd.GeoDataFrame(zipcodes_pickle, crs=my_crs, geometry=zipcodes_pickle.geometry)
zipcodes_pickle_gdf.head()
# Out:
#   ZCTA5CE10                                           geometry
# 0     43451  POLYGON ((-83.708733 41.32732599906431, -83.70...
# 1     43452  POLYGON ((-83.086978 41.53779599906346, -83.08...
# 2     43456  (POLYGON ((-82.835577 41.71082299906278, -82.8...
# 3     43457  POLYGON ((-83.496503 41.25370799906462, -83.48...
# 4     43458  POLYGON ((-83.222292 41.53102499906348, -83.22...

# %%
# plt.figure(figsize=(12, 12))
# zipcodes_pickle_gdf.plot(column="ZCTA5CE10")
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-21-c2ffba5f4304> in <module>
#       1 plt.figure(figsize=(12, 12))
# ----> 2 zipcodes_pickle_gdf.plot(column="ZCTA5CE10")
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     532         from there.
#     533         """
# --> 534         return plot_dataframe(self, *args, **kwargs)
#     535
#     536     plot.__doc__ = plot_dataframe.__doc__
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, **style_kwds)
#     506             ax.get_figure().colorbar(n_cmap, ax=ax)
#     507
# --> 508     plt.draw()
#     509     return ax
#     510
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/pyplot.py in draw()
#     714         fig.canvas.draw_idle()
#     715     """
# --> 716     get_current_fig_manager().canvas.draw_idle()
#     717
#     718
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/collections.py in draw(self, renderer)
#     253         renderer.open_group(self.__class__.__name__, self.get_gid())
#     254
# --> 255         self.update_scalarmappable()
#     256
#     257         transform, transOffset, offsets, paths = self._prepare_points()
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/collections.py in update_scalarmappable(self)
#     761             return
#     762         if self._is_filled:
# --> 763             self._facecolors = self.to_rgba(self._A, self._alpha)
#     764         elif self._is_stroked:
#     765             self._edgecolors = self.to_rgba(self._A, self._alpha)
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/cm.py in to_rgba(self, x, alpha, bytes, norm)
#     287         x = ma.asarray(x)
#     288         if norm:
# --> 289             x = self.norm(x)
#     290         rgba = self.cmap(x, alpha=alpha, bytes=bytes)
#     291         return rgba
#
# ~/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/matplotlib/colors.py in __call__(self, value, clip)
#     970             # ma division is very slow; we can take a shortcut
#     971             resdat = result.data
# --> 972             resdat -= vmin
#     973             resdat /= (vmax - vmin)
#     974             result = np.ma.array(resdat, mask=result.mask, copy=False)
#
# UFuncTypeError: ufunc 'subtract' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %%
geo_df = geo_df[['latitude', 'longitude', 'zip_code', 'city']]
geo_df.head()
# Out:
#   latitude longitude  zip_code        city
# 0  40.9223  -72.6371       501  Holtsville
# 1  40.9223  -72.6371       544  Holtsville
# 2  18.1653  -66.7226       601    Adjuntas
# 3  18.3931   -67.181       602      Aguada
# 4  18.4559  -67.1458       603   Aguadilla

# %%
# geo_df.dtypes
# Out:
# latitude     object
# longitude    object
# zip_code      int64
# city         object
# dtype: object

# %%
latt_long_df = pd.merge(final_df, geo_df, left_on="zipcode", right_on="zip_code")

# %%
latt_long_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 0 to 2
# Data columns (total 6 columns):
# zipcode           3 non-null int64
# amount_donated    3 non-null float64
# latitude          3 non-null object
# longitude         3 non-null object
# zip_code          3 non-null int64
# city              3 non-null object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 168.0+ bytes

# %%
my_zips = list(latt_long_df.zipcode.astype("str").values)
filtered_zips = zipcodes_pickle_gdf.loc[zipcodes_pickle_gdf["ZCTA5CE10"].isin(my_zips)]
filtered_zips["ZCTA5CE10"] = filtered_zips["ZCTA5CE10"].astype("int")
final_zip_area = pd.merge(filtered_zips, latt_long_df[["zipcode", "amount_donated"]], left_on="ZCTA5CE10", right_on="zipcode")
final_zip_area.head()
# Out:
# /Users/DannyBarker/workspace/backendCapstone/backendEnv/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    ZCTA5CE10                                           geometry  zipcode  \
# 0      37135  POLYGON ((-86.74854499999999 35.90986299910338...    37135
# 1      90201  (POLYGON ((-118.177048 33.99585199912495, -118...    90201
# 2      37027  POLYGON ((-86.88877599999999 36.01290199910233...    37027
#
#    amount_donated
# 0            0.26
# 1            0.67
# 2            1.76

# %%
# my_zips
# Out:
# ['37027', '37135', '90201']

# %%
quantiles = 10
# assign quantiles and colors for each county
final_zip_area['quantile'] = pd.qcut(final_zip_area['amount_donated'], quantiles, labels=False)
colors = sns.color_palette("Reds_r", int(1.25*quantiles)).as_hex() #Generate extra colors, so that the lowest is not totally white
final_zip_area['style'] = final_zip_area['quantile'].apply(
    lambda l: {
        'fillColor': colors[quantiles-1-int(l)], 
        'fillOpacity': 0.9,})

# %%
def generateBaseMap(default_location=[37.0902, -95.7129], default_zoom_start=4.1):
    base_map = folium.Map(location=default_location, control_scale=True, zoom_start=default_zoom_start)
    return base_map

# %%
base_map= generateBaseMap()

# folium.GeoJson(filtered_zips).add_to(base_map)

# plugins.HeatMap(data=latt_long_df[['latitude', 'longitude', 'amount_donated']].groupby(
#                             ['latitude', 'longitude']).sum(
#                             ).reset_index().values.tolist(),\
#                             radius=18, max_zoom=13).add_to(base_map)


for i in range(len(final_zip_area)):
    gs = folium.GeoJson(final_zip_area.iloc[i:i+1])
    label = '{}: ${}'.format(
        final_zip_area['zipcode'][i], final_zip_area['amount_donated'][i])
    folium.Popup(label).add_to(gs)
    gs.add_to(base_map)
    
# base_map.add_child(FastMarkerCluster(latt_long_df[['latitude', 'longitude']].values.tolist()))

mc = MarkerCluster()
#creating a Marker for each point in df_sample. Each point will get a popup with their zip
for idx,row in latt_long_df.iterrows():
    mc.add_child(folium.Marker(location=[row.latitude,  row.longitude],
                 popup=f"{row.zipcode}: ${str(round(float(row.amount_donated), 2))}))
 
base_map.add_child(mc)

base_map.save('capstone/templates/report/gift_cards.html')
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
